# %% [markdown]
# **LIMPAGEM DE DADOS DATASET RECEITAS**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

sns.set()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # *    **Teacher os arquivos de csv e Notepads de limpeza foram feitos utilizando o drive como maquina juntamente com o colab para a produção dos mesmos para facilitar ao puxar o repositorio caso precise testar algo é so colocar os csv's dentro da pasta Data sua que irá funcionar os Notebooks**

# %%
# Resposta:
from google.colab import drive
drive.mount('/content/drive')

# lê o arquivo CSV
df = pd.read_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/2022-09-01_Receitas_-_Base_de_Dados.csv',sep=';',encoding='latin-1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,3,5,7,8,9,10,11,12,13,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#                CD_RECEITA  CD_CATEGORIA         DESCRICAO_CATEGORIA  \
# 0              ----------  ------------         -------------------
# 1  6000030700000000000000             6  RECEITA EXTRA-ORÇAMENTÁRIA
# 2  1611010102020000000000             1          Receitas Correntes
# 3  1611010102020000000000             1          Receitas Correntes
# 4  1611010102020000000000             1          Receitas Correntes
#
#    CD_ORIGEM     DESCRICAO_ORIGEM  CD_ESPECIE  \
# 0  ---------     ----------------  ----------
# 1          0                  NaN           0
# 2          6  Receita de Serviços           1
# 3          6  Receita de Serviços           1
# 4          6  Receita de Serviços           1
#
#                               DESCRICAO_ESPECIE  CD_RUBRICA  \
# 0                             -----------------  ----------
# 1                                           NaN           0
# 2  SERVIÇOS ADMINISTRATIVOS E COMERCIAIS GERAIS         NaN
# ...

# %%
df.describe()
# Out:
#                     CD_RECEITA  CD_CATEGORIA DESCRICAO_CATEGORIA  CD_ORIGEM  \
# count                    91874         91874               91874      91874
# unique                     278             9                   5         17
# top     6000020100000000000000             1  Receitas Correntes          1
# freq                      8920         51998               80761      38080
#
#                                    DESCRICAO_ORIGEM  CD_ESPECIE  \
# count                                         81065       91874
# unique                                           14          15
# top     Impostos, Taxas e Contribuições de Melhoria           1
# freq                                          59029       33223
#
#        DESCRICAO_ESPECIE  CD_RUBRICA  DESCRICAO_RUBRICA  CD_ALINEA  \
# count              81063      9612.0                  1     9612.0
# unique                26         3.0                  1        9.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91874 entries, 0 to 91873
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CD_RECEITA           91874 non-null  object
#  1   CD_CATEGORIA         91874 non-null  object
#  2   DESCRICAO_CATEGORIA  91874 non-null  object
#  3   CD_ORIGEM            91874 non-null  object
#  4   DESCRICAO_ORIGEM     81065 non-null  object
#  5   CD_ESPECIE           91874 non-null  object
#  6   DESCRICAO_ESPECIE    81063 non-null  object
#  7   CD_RUBRICA           9612 non-null   object
#  8   DESCRICAO_RUBRICA    1 non-null      object
#  9   CD_ALINEA            9612 non-null   object
#  10  DESCRICAO_ALINEA     1 non-null      object
#  11  CD_SUBALINEA         9612 non-null   object
#  12  DESCRICAO_SUBALINEA  1 non-null      object
#  13  CD_EXERCICIO         91874 non-null  object
#  14  DT_APROPRIACAO       91874 non-null  object
# ...

# %% [markdown]
# Verifico a quantidade de Receitas

# %%
df.shape[0]
# Out:
# 91874

# %% [markdown]
# Removo a Primeira Linha devido a não possuir dados

# %%
df = df.drop(0)
df
# Out:
#                    CD_RECEITA CD_CATEGORIA         DESCRICAO_CATEGORIA  \
# 1      6000030700000000000000            6  RECEITA EXTRA-ORÇAMENTÁRIA
# 2      1611010102020000000000            1          Receitas Correntes
# 3      1611010102020000000000            1          Receitas Correntes
# 4      1611010102020000000000            1          Receitas Correntes
# 5      1611010102020000000000            1          Receitas Correntes
# ...                       ...          ...                         ...
# 91869  1113034101010000000000            1          Receitas Correntes
# 91870  1113034101010000000000            1          Receitas Correntes
# 91871  1113034101010000000000            1          Receitas Correntes
# 91872  1113034101010000000000            1          Receitas Correntes
# 91873  1321010111060100000000            1          Receitas Correntes
#
#       CD_ORIGEM                             DESCRICAO_ORIGEM CD_ESPECIE  \
# ...

# %% [markdown]
# Verifico novamente os dados do dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91873 entries, 1 to 91873
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CD_RECEITA           91873 non-null  object
#  1   CD_CATEGORIA         91873 non-null  object
#  2   DESCRICAO_CATEGORIA  91873 non-null  object
#  3   CD_ORIGEM            91873 non-null  object
#  4   DESCRICAO_ORIGEM     81064 non-null  object
#  5   CD_ESPECIE           91873 non-null  object
#  6   DESCRICAO_ESPECIE    81062 non-null  object
#  7   CD_RUBRICA           9611 non-null   object
#  8   DESCRICAO_RUBRICA    0 non-null      object
#  9   CD_ALINEA            9611 non-null   object
#  10  DESCRICAO_ALINEA     0 non-null      object
#  11  CD_SUBALINEA         9611 non-null   object
#  12  DESCRICAO_SUBALINEA  0 non-null      object
#  13  CD_EXERCICIO         91873 non-null  object
#  14  DT_APROPRIACAO       91873 non-null  object
# ...

# %% [markdown]
# Monto um dataset apenas com as colunas interessantes

# %%
df_aux = df[['CD_RECEITA', 'DESCRICAO_CATEGORIA', 'DESCRICAO_ORIGEM', 'DESCRICAO_ESPECIE', 'CD_EXERCICIO', 'DT_APROPRIACAO', 'TP_RECEITA_ORC','NM_EMPRESA','VL_RECEITA','DS_FONTE']]
df_aux
# Out:
#                    CD_RECEITA         DESCRICAO_CATEGORIA  \
# 1      6000030700000000000000  RECEITA EXTRA-ORÇAMENTÁRIA
# 2      1611010102020000000000          Receitas Correntes
# 3      1611010102020000000000          Receitas Correntes
# 4      1611010102020000000000          Receitas Correntes
# 5      1611010102020000000000          Receitas Correntes
# ...                       ...                         ...
# 91869  1113034101010000000000          Receitas Correntes
# 91870  1113034101010000000000          Receitas Correntes
# 91871  1113034101010000000000          Receitas Correntes
# 91872  1113034101010000000000          Receitas Correntes
# 91873  1321010111060100000000          Receitas Correntes
#
#                                   DESCRICAO_ORIGEM  \
# 1                                              NaN
# 2                              Receita de Serviços
# 3                              Receita de Serviços
# 4                              Receita de Serviços
# ...

# %% [markdown]
# Verifico Linhas em Branco

# %%
df_aux[df_aux.isna().any(axis=1)]
# Out:
#                    CD_RECEITA         DESCRICAO_CATEGORIA DESCRICAO_ORIGEM  \
# 1      6000030700000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 563    6000990201000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 596    6000990202000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 861    6000991109000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 1066   6000030400000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# ...                       ...                         ...              ...
# 91841  6000990204000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 91842  6000990204000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 91843  6000990204000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 91844  6000990201000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
# 91845  6000990201000000000000  RECEITA EXTRA-ORÇAMENTÁRIA              NaN
#
# ...

# %%
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91873 entries, 1 to 91873
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CD_RECEITA           91873 non-null  object
#  1   DESCRICAO_CATEGORIA  91873 non-null  object
#  2   DESCRICAO_ORIGEM     81064 non-null  object
#  3   DESCRICAO_ESPECIE    81062 non-null  object
#  4   CD_EXERCICIO         91873 non-null  object
#  5   DT_APROPRIACAO       91873 non-null  object
#  6   TP_RECEITA_ORC       91873 non-null  object
#  7   NM_EMPRESA           91873 non-null  object
#  8   VL_RECEITA           91873 non-null  object
#  9   DS_FONTE             91873 non-null  object
# dtypes: object(10)
# memory usage: 7.7+ MB

# %% [markdown]
# Preencho os dados de Especie e Origem de dados Extra-Orçamentários com "Desconhecido" para possibilitar o tratamento de dados sem valores

# %%
df_aux['DESCRICAO_ORIGEM'] = df_aux['DESCRICAO_ORIGEM'].fillna("Desconhecido")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_aux['DESCRICAO_ESPECIE'] = df_aux['DESCRICAO_ESPECIE'].fillna("Desconhecido")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91873 entries, 1 to 91873
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CD_RECEITA           91873 non-null  object
#  1   DESCRICAO_CATEGORIA  91873 non-null  object
#  2   DESCRICAO_ORIGEM     91873 non-null  object
#  3   DESCRICAO_ESPECIE    91873 non-null  object
#  4   CD_EXERCICIO         91873 non-null  object
#  5   DT_APROPRIACAO       91873 non-null  object
#  6   TP_RECEITA_ORC       91873 non-null  object
#  7   NM_EMPRESA           91873 non-null  object
#  8   VL_RECEITA           91873 non-null  object
#  9   DS_FONTE             91873 non-null  object
# dtypes: object(10)
# memory usage: 7.7+ MB

# %% [markdown]
# Renomeio as Colunas para nomes mais amigaveis

# %%
df_aux = df_aux.rename(columns={'CD_RECEITA': 'Codigo','DESCRICAO_CATEGORIA': 'Categoria','DESCRICAO_ORIGEM': 'Origem','DESCRICAO_ESPECIE': 'Especie','CD_EXERCICIO': 'Cod_Exercicio','DT_APROPRIACAO': 'Data','DESCRICAO_ESPECIE': 'Especie','TP_RECEITA_ORC': 'Tipo','NM_EMPRESA': 'Empresa','VL_RECEITA': 'Valor','DS_FONTE': 'Fonte'})

# %%
df_aux.head(10)
# Out:
#                     Codigo                   Categoria               Origem  \
# 1   6000030700000000000000  RECEITA EXTRA-ORÇAMENTÁRIA         Desconhecido
# 2   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 3   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 4   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 5   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 6   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 7   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 8   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 9   1611010102020000000000          Receitas Correntes  Receita de Serviços
# 10  1611010102020000000000          Receitas Correntes  Receita de Serviços
#
#                                          Especie Cod_Exercicio        Data  \
# ...

# %% [markdown]
# Substituir Tipos e definir os tipos corretamente.

# %% [markdown]
# Havia Transformado o dado em Float devido a Integer ser muito grande porém na etapa de análise exploratória encontrei problemas então decidi manter como string

# %%
#df_aux['Codigo'] = df_aux['Codigo'].astype(float)

# %%
df_aux['Cod_Exercicio'] = df_aux['Cod_Exercicio'].astype(int)

# %% [markdown]
# Verifico o Campo Data para identificar se não há nenhum registro diferenciado

# %%
df_aux['Data'].unique
# Out:
# <bound method Series.unique of 1        2022-08-31
# 2        2022-07-27
# 3        2022-07-26
# 4        2022-07-26
# 5        2022-07-26
#             ...
# 91869    2022-08-09
# 91870    2022-08-10
# 91871    2022-08-10
# 91872    2022-08-10
# 91873    2022-07-31
# Name: Data, Length: 91873, dtype: object>

# %%
df_aux['Data'] = pd.to_datetime(df_aux['Data'], format='%Y-%m-%d')

# %% [markdown]
# Convertendo virgula para ponto para trabalhar com valores

# %%
df_aux['Valor'] = df_aux['Valor'].str.replace(',', '.')

# %%
df_aux['Valor'] = df_aux['Valor'].astype(float)

# %%
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91873 entries, 1 to 91873
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Codigo         91873 non-null  object
#  1   Categoria      91873 non-null  object
#  2   Origem         91873 non-null  object
#  3   Especie        91873 non-null  object
#  4   Cod_Exercicio  91873 non-null  int64
#  5   Data           91873 non-null  datetime64[ns]
#  6   Tipo           91873 non-null  object
#  7   Empresa        91873 non-null  object
#  8   Valor          91873 non-null  float64
#  9   Fonte          91873 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 7.7+ MB

# %%
df_aux.head()
# Out:
#                    Codigo                   Categoria               Origem  \
# 1  6000030700000000000000  RECEITA EXTRA-ORÇAMENTÁRIA         Desconhecido
# 2  1611010102020000000000          Receitas Correntes  Receita de Serviços
# 3  1611010102020000000000          Receitas Correntes  Receita de Serviços
# 4  1611010102020000000000          Receitas Correntes  Receita de Serviços
# 5  1611010102020000000000          Receitas Correntes  Receita de Serviços
#
#                                         Especie  Cod_Exercicio       Data  \
# 1                                  Desconhecido           2022 2022-08-31
# 2  SERVIÇOS ADMINISTRATIVOS E COMERCIAIS GERAIS           2022 2022-07-27
# 3  SERVIÇOS ADMINISTRATIVOS E COMERCIAIS GERAIS           2022 2022-07-26
# 4  SERVIÇOS ADMINISTRATIVOS E COMERCIAIS GERAIS           2022 2022-07-26
# 5  SERVIÇOS ADMINISTRATIVOS E COMERCIAIS GERAIS           2022 2022-07-26
#
# ...

# %% [markdown]
# Verifico os registros de strings para ver padronização

# %%
df_aux['Categoria'].unique()
# Out:
# array(['RECEITA EXTRA-ORÇAMENTÁRIA', 'Receitas Correntes',
#        'Receitas de Capital', 'RECEITAS CORRENTES INTRAORÇAMENTÁRIAS'],
#       dtype=object)

# %% [markdown]
# Faço com que os dados categoricos fiquem com letras minusculas

# %%
df_aux['Categoria'] = df_aux['Categoria'].str.lower()

# %%
df_aux['Categoria'].unique()
# Out:
# array(['receita extra-orçamentária', 'receitas correntes',
#        'receitas de capital', 'receitas correntes intraorçamentárias'],
#       dtype=object)

# %%
df_aux['Origem'].unique()
# Out:
# array(['Desconhecido', 'Receita de Serviços',
#        'Impostos, Taxas e Contribuições de Melhoria',
#        'Receita Patrimonial', 'Transferências Correntes',
#        'Outras Receitas Correntes', 'Outras Receitas de Capital',
#        'OUTRAS RECEITAS CORRENTES INTRAORÇAMENTÁRIAS', 'Contribuições',
#        'RECEITAS DE CONTRIBUIÇÕES INTRAORÇAMENTÁRIAS',
#        'Transferências de Capital',
#        'RECEITA DE SERVIÇOS INTRAORÇAMENTÁRIA', 'Operações de Crédito',
#        'RECEITA PATRIMONIAL INTRAORÇAMENTÁRIA'], dtype=object)

# %%
df_aux['Origem'] = df_aux['Origem'].str.lower()

# %%
df_aux['Origem'].unique()
# Out:
# array(['desconhecido', 'receita de serviços',
#        'impostos, taxas e contribuições de melhoria',
#        'receita patrimonial', 'transferências correntes',
#        'outras receitas correntes', 'outras receitas de capital',
#        'outras receitas correntes intraorçamentárias', 'contribuições',
#        'receitas de contribuições intraorçamentárias',
#        'transferências de capital',
#        'receita de serviços intraorçamentária', 'operações de crédito',
#        'receita patrimonial intraorçamentária'], dtype=object)

# %%
df_aux['Especie'].unique()
# Out:
# array(['Desconhecido', 'SERVIÇOS ADMINISTRATIVOS E COMERCIAIS GERAIS',
#        'IMPOSTOS', 'VALORES MOBILIÁRIOS',
#        'DEMAIS TRANSFERÊNCIAS CORRENTES', 'DEMAIS RECEITAS CORRENTES',
#        'EXPLORAÇÃO DO PATRIMÔNIO IMOBILIÁRIO DO ESTADO',
#        'DEMAIS RECEITAS DE CAPITAL',
#        'TRANSFERÊNCIAS DE OUTRAS INSTITUIÇÕES PÚBLICAS',
#        'TRANSFERÊNCIAS DOS ESTADOS E DO DISTRITO FEDERAL E DE SUAS ENTIDADES',
#        'TRANSFERÊNCIAS DE INSTITUIÇÕES PRIVADAS', 'TAXAS',
#        'SERVIÇOS E ATIVIDADES REFERENTES À NAVEGAÇÃO E AO TRANSPORTE',
#        'INDENIZAÇÕES, RESTITUIÇÕES E RESSARCIMENTOS',
#        'MULTAS ADMINISTRATIVAS, CONTRATUAIS E JUDICIAIS',
#        'OUTROS SERVIÇOS', 'TRANSFERÊNCIAS DA UNIÃO E DE SUAS ENTIDADES',
#        'RECEITAS DIVERSAS', 'CONTRIBUIÇÕES SOCIAIS',
#        'CONTRIBUIÇÃO DE MELHORIA',
#        'DELEGAÇÃO DE SERVIÇOS PÚBLICOS MEDIANTE CONCESSÃO, PERMISSÃO, AUTORIZAÇÃO OU LICENÇA',
#        'DEMAIS RECEITAS PATRIMONIAIS',
# ...

# %%
df_aux['Especie'] = df_aux['Especie'].str.lower()

# %%
df_aux['Especie'].unique()
# Out:
# array(['desconhecido', 'serviços administrativos e comerciais gerais',
#        'impostos', 'valores mobiliários',
#        'demais transferências correntes', 'demais receitas correntes',
#        'exploração do patrimônio imobiliário do estado',
#        'demais receitas de capital',
#        'transferências de outras instituições públicas',
#        'transferências dos estados e do distrito federal e de suas entidades',
#        'transferências de instituições privadas', 'taxas',
#        'serviços e atividades referentes à navegação e ao transporte',
#        'indenizações, restituições e ressarcimentos',
#        'multas administrativas, contratuais e judiciais',
#        'outros serviços', 'transferências da união e de suas entidades',
#        'receitas diversas', 'contribuições sociais',
#        'contribuição de melhoria',
#        'delegação de serviços públicos mediante concessão, permissão, autorização ou licença',
#        'demais receitas patrimoniais',
# ...

# %%
df_aux['Tipo'].unique()
# Out:
# array(['Extra-Orçamentária', 'Orçamentária'], dtype=object)

# %%
df_aux['Empresa'].unique()
# Out:
# array(['Fundo de Urbanização de Curitiba',
#        'Fundo de Abastecimento Alimentar de Curitiba',
#        'Prefeitura Municipal de Curitiba',
#        'Fundo Municipal para Criança e o Adolescente',
#        'Fundação Cultural de Curitiba', 'Fundo Municipal da Cultura',
#        'Fundo Municipal dos Direitos da Pessoa Idosa',
#        'Instituto de Previdência dos Servid. Mun. Curitiba',
#        'Instituto de Pesquisa e Planej. Urbano de Curitiba',
#        'Fundo Municipal de Assistência Social', 'Fundação de Ação Social',
#        'Instituto Municipal de Administração Pública',
#        'Fundo Municipal da Saúde', 'Instituto Municipal de Turismo',
#        'Fundo Municipal de Habitação de Interesse Social',
#        'Fundo Municipal de Defesa Civil', 'Fundo Municipal do Trabalho',
#        'Fundo Municipal de Apoio ao Deficiente'], dtype=object)

# %%
df_aux['Fonte'].unique()
# Out:
# array(['Retenções em Carater Consignatório',
#        'Recursos Próprios do Fundo de Abastecimento Alimentar de Curitiba',
#        'Recursos Ordinários (Livres)',
#        'Demais Impostos Vinculados à Educação Básica',
#        'Saúde - Receitas Vinculadas (EC 29/00 - 15%)',
#        'Termo de Concordância - Shopping Palladium',
#        'Medida Compensatória Licenciamento Ambiental - LI nº 017/2001 - UNIBRASIL',
#        'Fundo de Reserva Depósitos Judiciais (Lei 10819/03, art.3º)',
#        'Receitas de Alienações de Ativos',
#        'Recursos de Operações de Crédito - FDU',
#        'Recursos de Operações de Crédito - FONPLATA',
#        'Programa de Infra-Estrutura Para Mobilidade Urbana - Pro-Mob',
#        'Operações de Crédito - BID III',
#        'COSIP - Contribuição de Iluminação Pública, Art. 149-A, CF',
#        'Taxas - Exercício Poder de Polícia',
#        'Taxas - Prestação de Serviços',
#        'Termos de Compromissos - Medidas Compensatórias',
# ...

# %% [markdown]
# Verifico os dados novamente após tratativas

# %%
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91873 entries, 1 to 91873
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Codigo         91873 non-null  object
#  1   Categoria      91873 non-null  object
#  2   Origem         91873 non-null  object
#  3   Especie        91873 non-null  object
#  4   Cod_Exercicio  91873 non-null  int64
#  5   Data           91873 non-null  datetime64[ns]
#  6   Tipo           91873 non-null  object
#  7   Empresa        91873 non-null  object
#  8   Valor          91873 non-null  float64
#  9   Fonte          91873 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 7.7+ MB

# %%
print('Média de Receitas: ', df_aux['Valor'].mean())

df_aux.set_index('Data')['Valor'].plot()
# Out:
# Média de Receitas:  34569.32040577754

# %%
df_aux2 = df_aux

# %% [markdown]
# Indentificado Primeiro outlier no qual os campos de valor estão negativos , devido ao dicionario não informar e o senso comum ifentificar que estes valores devem ser positivos devidos a serem Receitas neste caso esses valores serão desconsiderados na análise

# %%
df_aux2[df_aux2['Valor'] <= 0]
# Out:
#                        Codigo           Categoria                    Origem  \
# 615    1721500102000000000000  receitas correntes  transferências correntes
# 766    1721510102000000000000  receitas correntes  transferências correntes
# 1273   1321010111060100000000  receitas correntes       receita patrimonial
# 1274   1321010111060100000000  receitas correntes       receita patrimonial
# 1295   1321010111060100000000  receitas correntes       receita patrimonial
# ...                       ...                 ...                       ...
# 88021  1711511102000000000000  receitas correntes  transferências correntes
# 88115  1791990101000000000000  receitas correntes  transferências correntes
# 91164  1711520102000000000000  receitas correntes  transferências correntes
# 91165  1711520102000000000000  receitas correntes  transferências correntes
# 91568  1721520101000000000000  receitas correntes  transferências correntes
#
# ...

# %% [markdown]
# Sendo assim filtramos os valores para que sejam maiores que zero para que a análise fique coerente

# %%
df_aux = df_aux[df_aux['Valor'] > 0]

# %%
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90874 entries, 1 to 91873
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Codigo         90874 non-null  object
#  1   Categoria      90874 non-null  object
#  2   Origem         90874 non-null  object
#  3   Especie        90874 non-null  object
#  4   Cod_Exercicio  90874 non-null  int64
#  5   Data           90874 non-null  datetime64[ns]
#  6   Tipo           90874 non-null  object
#  7   Empresa        90874 non-null  object
#  8   Valor          90874 non-null  float64
#  9   Fonte          90874 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 7.6+ MB

# %%
print('Média de Receitas: ', df_aux['Valor'].mean())

df_aux.set_index('Data')['Valor'].plot()
# Out:
# Média de Receitas:  36200.22686422959

# %% [markdown]
# Agora com um dataset mais coerente com relação a seus valores e campos tratados podemos salvar e continuar para a análise exploratória

# %%
df_aux.to_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/Receitas_Base_de_Dados_Limpo.csv', index=False, encoding='latin-1')
